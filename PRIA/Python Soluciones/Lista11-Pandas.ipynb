# %% [markdown]
# # LISTA 11 - PANDAS

# %% [markdown]
# ## <ins>Ejercicios Obligatorios </ins>

# %% [markdown]
# ## EJERCICIO 1

# %% [markdown]
# Crea un dataframe con 15 filas y 2 columnas. La primera columna se llamará x, la segunda y. Cada entrada será un número aleatorio (puedes usar random.normal() de la librería numpy). Guarda el dataframe en una variable llamada points.

# %%
import pandas as pd
import numpy as np
x = np.random.normal(0,1,15)
y = np.random.normal(0,2,15)
print(x)
print(y)
data=list(zip(x,y))
print(data)
points=pd.DataFrame(data,columns=["x","y"])
print(points)
# Out:
# [-0.81897175  0.95002749  2.21437466 -1.07730386 -0.30757386  0.3600536
#   0.39245219  0.18508456 -0.06452021 -0.20913799 -1.02397525  0.00287526
#   0.30574094  0.7546293   0.41047629]
# [-0.65088736  0.1492397  -1.5158099   0.7104905  -3.31710705  4.52719093
#   4.58994961  0.98818186 -3.84395027 -1.57511543  0.6526283  -0.07389126
#  -0.05702181  0.37958112 -1.44400185]
# [(-0.8189717520710473, -0.6508873561059212), (0.9500274855657141, 0.14923970184509794), (2.2143746632506867, -1.5158098964714222), (-1.0773038608224754, 0.7104905003705138), (-0.3075738582090853, -3.3171070512760736), (0.3600535977123712, 4.527190928826665), (0.3924521863653896, 4.589949608964549), (0.18508455763881504, 0.9881818565510989), (-0.06452021345853778, -3.843950270237065), (-0.20913798817475823, -1.575115428353918), (-1.0239752536865823, 0.6526283029640162), (0.002875264853302515, -0.07389126382747754), (0.3057409422628405, -0.057021806094655535), (0.7546293008991001, 0.3795811174030118), (0.4104762943860435, -1.4440018527838385)]
#            x         y
# 0  -0.818972 -0.650887
# 1   0.950027  0.149240
# 2   2.214375 -1.515810
# 3  -1.077304  0.710491
# 4  -0.307574 -3.317107
# 5   0.360054  4.527191
# 6   0.392452  4.589950
# 7   0.185085  0.988182
# 8  -0.064520 -3.843950
# 9  -0.209138 -1.575115
# 10 -1.023975  0.652628
# 11  0.002875 -0.073891
# 12  0.305741 -0.057022
# 13  0.754629  0.379581
# 14  0.410476 -1.444002

# %% [markdown]
# ## EJERCICIO 2

# %% [markdown]
# Del dataframe points, muestra las filas cuyo valor en la columna x sea positivo.

# %%
print(points[points["x"]>=0])
# Out:
#            x         y
# 1   0.250463  2.059132
# 2   0.964532  0.018502
# 3   1.300063 -0.976910
# 5   0.256966 -3.102549
# 6   0.012045 -2.922127
# 7   0.446826 -0.620734
# 8   0.693974 -0.163339
# 9   0.032064 -0.383971
# 12  0.915635 -1.938813
# 14  0.345366  0.120039

# %% [markdown]
# ## EJERCICIO 3

# %% [markdown]
# Del dataframe points, muestra las filas cuyo valor en la columna y sea negativo.

# %%
print(points.query('y<0'))
# Out:
#            x         y
# 0  -1.309199 -2.075410
# 3   1.300063 -0.976910
# 5   0.256966 -3.102549
# 6   0.012045 -2.922127
# 7   0.446826 -0.620734
# 8   0.693974 -0.163339
# 9   0.032064 -0.383971
# 10 -0.466960 -2.029524
# 12  0.915635 -1.938813
# 13 -1.278029 -2.602068

# %% [markdown]
# ## EJERCICIO 4

# %% [markdown]
# Del dataframe points, muestra las observaciones cuyos puntos (x, y) pertenezcan al primer cuadrante.

# %%
print(points.query('y>0 and x>0'))

filtro=(points["x"] >= 0) & (points["y"] >= 0)
print(points[filtro])
# Out:
#            x         y
# 1   0.250463  2.059132
# 2   0.964532  0.018502
# 14  0.345366  0.120039
#            x         y
# 1   0.250463  2.059132
# 2   0.964532  0.018502
# 14  0.345366  0.120039

# %% [markdown]
# ## EJERCICIO 5

# %% [markdown]
# Del dataframe points, muestra las observaciones de la forma: “El punto ({x}, {y}) {no/sí} pertenece al primer cuadrante”.

# %%
for j in points.itertuples():
    cuadrante1="no"
    if j[0]>=0 and j[1]>=0:
        cuadrante1="si"
    print("El punto ({:.2f},{:.2f}) {} pertenece al primer cuadrante".format(j[0],j[1],cuadrante1))
# Out:
# El punto (0.00,0.75) si pertenece al primer cuadrante
# El punto (1.00,1.86) si pertenece al primer cuadrante
# El punto (2.00,-1.20) no pertenece al primer cuadrante
# El punto (3.00,0.52) si pertenece al primer cuadrante
# El punto (4.00,-0.41) no pertenece al primer cuadrante
# El punto (5.00,0.69) si pertenece al primer cuadrante
# El punto (6.00,1.02) si pertenece al primer cuadrante
# El punto (7.00,-0.29) no pertenece al primer cuadrante
# El punto (8.00,-1.89) no pertenece al primer cuadrante
# El punto (9.00,-0.43) no pertenece al primer cuadrante
# El punto (10.00,-0.60) no pertenece al primer cuadrante
# El punto (11.00,-0.73) no pertenece al primer cuadrante
# El punto (12.00,-0.71) no pertenece al primer cuadrante
# El punto (13.00,-0.55) no pertenece al primer cuadrante
# El punto (14.00,0.68) si pertenece al primer cuadrante

# %% [markdown]
# ## EJERCICIO 6

# %% [markdown]
# Crea un dataframe con 10 filas y 4 columnas. La primera columna se llamará word; la segunda, length; la tercera, vowels; y la última, consonants. La columna words contendrá las siguientes 10 palabras: “euro”, “diez” “algas”, “broma”, “cicuta”, “fatiga”, “nachos”, “jadeos”, “hazañas”, “boutique”. Las columnas length, vowels y consonants contendrán, respectivamente, la longitud, el total de vocales y el total de consonantes (añade las columnas calculando su valor por código). Guarda el dataframe en la variable words.

# %%
import pandas as pd

def contarVocales(palabra):
    numVocales=0
    palabra=palabra.lower()
    for c in palabra:
        if c in "aeiou":
            numVocales+=1
    return numVocales

def contarConsonantes(palabra):
    numConsonantes=0
    palabra=palabra.lower()
    for c in palabra:
        if c in "bcdfghjklmnñpqrstvwxyz":
            numConsonantes+=1
    return numConsonantes

palabras = ["euro", "diez", "algas", "broma", "cicuta", "fatiga", "nachos", "jadeos", "hazañas", "boutique"]
data = {"words": palabras, "length": list(map(len,palabras)), "vocals": list(map(contarVocales,palabras)), "consonants": list(map(contarConsonantes,palabras))}
words=pd.DataFrame(data)
print(words)
# Out:
#       words  length  vocals  consonants
# 0      euro       4       3           1
# 1      diez       4       2           2
# 2     algas       5       2           3
# 3     broma       5       2           3
# 4    cicuta       6       3           3
# 5    fatiga       6       3           3
# 6    nachos       6       2           4
# 7    jadeos       6       3           3
# 8   hazañas       7       3           4
# 9  boutique       8       5           3

# %% [markdown]
# ## EJERCICIO 7

# %% [markdown]
# Muestra las 10 observaciones de words con el formato “La palabra {word} tiene {length} letras, de las cuales {vowels} son vocales y {consonants} consonantes”.

# %%
for obsv in words.itertuples():
    print("La palabra {} tiene {} letras, de las cuales {} son vocales y {} consonantes".format(obsv[1],obsv[2],obsv[3],obsv[4]))
# Out:
# La palabra euro tiene 4 letras, de las cuales 3 son vocales y 1 consonantes
# La palabra diez tiene 4 letras, de las cuales 2 son vocales y 2 consonantes
# La palabra algas tiene 5 letras, de las cuales 2 son vocales y 3 consonantes
# La palabra broma tiene 5 letras, de las cuales 2 son vocales y 3 consonantes
# La palabra cicuta tiene 6 letras, de las cuales 3 son vocales y 3 consonantes
# La palabra fatiga tiene 6 letras, de las cuales 3 son vocales y 3 consonantes
# La palabra nachos tiene 6 letras, de las cuales 2 son vocales y 4 consonantes
# La palabra jadeos tiene 6 letras, de las cuales 3 son vocales y 3 consonantes
# La palabra hazañas tiene 7 letras, de las cuales 3 son vocales y 4 consonantes
# La palabra boutique tiene 8 letras, de las cuales 5 son vocales y 3 consonantes

# %% [markdown]
# ## EJERCICIO 8

# %% [markdown]
# Muestra aquellas observaciones de words que tienen el mismo número de vocales y consonantes.

# %%
print(words.query('vocals==consonants'))

print(words[words["vocals"]==words["consonants"]])
# Out:
#     words  length  vocals  consonants
# 1    diez       4       2           2
# 4  cicuta       6       3           3
# 5  fatiga       6       3           3
# 7  jadeos       6       3           3
#     words  length  vocals  consonants
# 1    diez       4       2           2
# 4  cicuta       6       3           3
# 5  fatiga       6       3           3
# 7  jadeos       6       3           3

# %% [markdown]
# ## EJERCICIO 9

# %% [markdown]
# El siguiente DataFrame contiene información de los pisos en alquiler en Murcia a fecha de 31/12/2020:
# ```
# fotocasa_df = pd.read_csv("https://drive.google.com/uc?export=view&id=1DwvALe87aeDzTk7s6xGPDd6itJ65s4YE", index_col = 0)
# ```
# Muestra el número de filas, columnas y valores que contiene el DataFrame cargado:

# %%
fotocasa_df = pd.read_csv("https://drive.google.com/uc?export=view&id=1DwvALe87aeDzTk7s6xGPDd6itJ65s4YE", index_col = 0)
# Filas:
print(f"Número de filas (1): {len(fotocasa_df)}")
print(f"Número de filas (2): {len(fotocasa_df.index)}")
print(f"Número de filas (3): {fotocasa_df.shape[0]}")
# Columnas
print(f"Número de columnas (1): {len(fotocasa_df.columns)}")
print(f"Número de columnas (2): {fotocasa_df.shape[1]}")
# Valores
print(f"Número de valores (1): {fotocasa_df.size}")
print(f"Número de valores (2): {fotocasa_df.shape[0] * fotocasa_df.shape[1]}")
# Out:
# Número de filas (1): 617
# Número de filas (2): 617
# Número de filas (3): 617
# Número de columnas (1): 59
# Número de columnas (2): 59
# Número de valores (1): 36403
# Número de valores (2): 36403

# %% [markdown]
# ## EJERCICIO 10

# %% [markdown]
# Recupera los cinco primeros pisos (filas)

# %%
fotocasa_df.head()
# Out:
#         Precio                                     Título  \
# 0  A consultar                 Piso de alquiler en Centro
# 1   500 € /mes          Apartamento de alquiler en Centro
# 2   900 € /mes  Piso de alquiler en Doctor Marañón Centro
# 3   750 € /mes                 Piso de alquiler en Centro
# 4   800 € /mes                 Piso de alquiler en Centro
#
#                                          Descripción     Fotos  \
# 0  TRABAJADORES Y ESTUDIANTES ATENCION!!!! VIVIEN...  18 Fotos
# 1  Maravilloso apartamento para entrar a vivir en...  21 Fotos
# 2  Se alquila estupenda vivienda recién reformada...  18 Fotos
# 3  Te presentamos este fabuloso apartamento situa...  30 Fotos
# 4  Fantástica vivienda en alquiler ubicada muy pr...  28 Fotos
#
#                Dirección  Inmobiliaria                    Anunciante  \
# 0                 Centro          True      DPTO. COMERCIAL PISOSMUR
# 1                 Centro          True                BREXTOM MURCIA
# 2  Doctor Marañón Centro          True  ABAD SERVICIOS INMOBILIARIOS
# 3                 Centro          True  ABAD SERVICIOS INMOBILIARIOS
# 4                 Centro          True                BREXTOM MURCIA
#
#                         Habitaciones                              Baños  \
# 0  <span><span>4</span> habs.</span>  <span><span>2</span> baños</span>
# 1   <span><span>1</span> hab.</span>   <span><span>1</span> baño</span>
# 2  <span><span>4</span> habs.</span>  <span><span>2</span> baños</span>
# 3  <span><span>2</span> habs.</span>   <span><span>1</span> baño</span>
# 4  <span><span>3</span> habs.</span>  <span><span>2</span> baños</span>
#
#                          Superficie  ... Serv. portería Internet  \
# 0  <span><span>110</span> m²</span>  ...            NaN      NaN
# 1   <span><span>46</span> m²</span>  ...            NaN      NaN
# 2  <span><span>169</span> m²</span>  ...            NaN      NaN
# 3   <span><span>77</span> m²</span>  ...            NaN      NaN
# 4  <span><span>104</span> m²</span>  ...            NaN      NaN
#
#   Suite - con baño Patio Domótica Pista de Tenis Alarma Mascotas  \
# 0              NaN   NaN      NaN            NaN    NaN      NaN
# 1              NaN   NaN      NaN            NaN    NaN      NaN
# 2              NaN   NaN      NaN            NaN    NaN      NaN
# 3              NaN   NaN      NaN            NaN    NaN      NaN
# 4              NaN   NaN      NaN            NaN    NaN      NaN
#
#   Energía Solar Gimnasio
# 0           NaN      NaN
# 1           NaN      NaN
# 2           NaN      NaN
# 3           NaN      NaN
# 4           NaN      NaN
#
# [5 rows x 59 columns]

# %% [markdown]
# ## EJERCICIO 11

# %% [markdown]
# Recupera los cinco últimos pisos:

# %%
fotocasa_df.tail()
# Out:
#     Precio                                             Título Descripción  \
# 612    NaN  Alquiler piso en barrio dEl Carmen en El Carme...         NaN
# 613    NaN  Alquiler apartamento en plaza san nicolas en M...         NaN
# 614    NaN  Alquiler apartamento exclusivo apto plaza flor...         NaN
# 615    NaN  Alquiler piso alquiler de local entresuelo en ...         NaN
# 616    NaN  Alquiler piso en alquiler en edificio alba, sa...         NaN
#
#     Fotos Dirección  Inmobiliaria Anunciante Habitaciones Baños Superficie  \
# 612   NaN       NaN          True        NaN          NaN   NaN        NaN
# 613   NaN       NaN          True        NaN          NaN   NaN        NaN
# 614   NaN       NaN          True        NaN          NaN   NaN        NaN
# 615   NaN       NaN          True        NaN          NaN   NaN        NaN
# 616   NaN       NaN          True        NaN          NaN   NaN        NaN
#
#      ... Serv. portería Internet Suite - con baño Patio Domótica  \
# 612  ...            NaN      NaN              NaN   NaN      NaN
# 613  ...            NaN      NaN              NaN   NaN      NaN
# 614  ...            NaN      NaN              NaN   NaN      NaN
# 615  ...            NaN      NaN              NaN   NaN      NaN
# 616  ...            NaN      NaN              NaN   NaN      NaN
#
#     Pista de Tenis Alarma Mascotas Energía Solar Gimnasio
# 612            NaN    NaN      NaN           NaN      NaN
# 613            NaN    NaN      NaN           NaN      NaN
# 614            NaN    NaN      NaN           NaN      NaN
# 615            NaN    NaN      NaN           NaN      NaN
# 616            NaN    NaN      NaN           NaN      NaN
#
# [5 rows x 59 columns]

# %% [markdown]
# ## EJERCICIO 12

# %% [markdown]
# Las columnas Domótica, Pista de Tenis, Alarma, Mascotas, Energía Solar y Gimnasio no contienen apenas valores definidos. Elimínalas del DataFrame y almacena el resultado en fotocasa1_df:

# %%
fotocasa1_df = fotocasa_df.drop(['Pista de Tenis', 'Alarma', 'Mascotas', 'Energía Solar', 'Gimnasio'], axis=1)
fotocasa1_df
# Out:
#           Precio                                             Título  \
# 0    A consultar                         Piso de alquiler en Centro
# 1     500 € /mes                  Apartamento de alquiler en Centro
# 2     900 € /mes          Piso de alquiler en Doctor Marañón Centro
# 3     750 € /mes                         Piso de alquiler en Centro
# 4     800 € /mes                         Piso de alquiler en Centro
# ..           ...                                                ...
# 612          NaN  Alquiler piso en barrio dEl Carmen en El Carme...
# 613          NaN  Alquiler apartamento en plaza san nicolas en M...
# 614          NaN  Alquiler apartamento exclusivo apto plaza flor...
# 615          NaN  Alquiler piso alquiler de local entresuelo en ...
# 616          NaN  Alquiler piso en alquiler en edificio alba, sa...
#
#                                            Descripción     Fotos  \
# 0    TRABAJADORES Y ESTUDIANTES ATENCION!!!! VIVIEN...  18 Fotos
# 1    Maravilloso apartamento para entrar a vivir en...  21 Fotos
# 2    Se alquila estupenda vivienda recién reformada...  18 Fotos
# 3    Te presentamos este fabuloso apartamento situa...  30 Fotos
# 4    Fantástica vivienda en alquiler ubicada muy pr...  28 Fotos
# ..                                                 ...       ...
# 612                                                NaN       NaN
# 613                                                NaN       NaN
# 614                                                NaN       NaN
# 615                                                NaN       NaN
# 616                                                NaN       NaN
#
#                  Dirección  Inmobiliaria                    Anunciante  \
# 0                   Centro          True      DPTO. COMERCIAL PISOSMUR
# 1                   Centro          True                BREXTOM MURCIA
# 2    Doctor Marañón Centro          True  ABAD SERVICIOS INMOBILIARIOS
# 3                   Centro          True  ABAD SERVICIOS INMOBILIARIOS
# 4                   Centro          True                BREXTOM MURCIA
# ..                     ...           ...                           ...
# 612                    NaN          True                           NaN
# 613                    NaN          True                           NaN
# 614                    NaN          True                           NaN
# 615                    NaN          True                           NaN
# 616                    NaN          True                           NaN
#
#                           Habitaciones                              Baños  \
# 0    <span><span>4</span> habs.</span>  <span><span>2</span> baños</span>
# 1     <span><span>1</span> hab.</span>   <span><span>1</span> baño</span>
# 2    <span><span>4</span> habs.</span>  <span><span>2</span> baños</span>
# 3    <span><span>2</span> habs.</span>   <span><span>1</span> baño</span>
# 4    <span><span>3</span> habs.</span>  <span><span>2</span> baños</span>
# ..                                 ...                                ...
# 612                                NaN                                NaN
# 613                                NaN                                NaN
# 614                                NaN                                NaN
# 615                                NaN                                NaN
# 616                                NaN                                NaN
#
#                            Superficie  ... Piscina   TV Zona Deportiva  \
# 0    <span><span>110</span> m²</span>  ...     NaN  NaN            NaN
# 1     <span><span>46</span> m²</span>  ...     NaN  NaN            NaN
# 2    <span><span>169</span> m²</span>  ...     NaN  NaN            NaN
# 3     <span><span>77</span> m²</span>  ...     NaN  NaN            NaN
# 4    <span><span>104</span> m²</span>  ...     NaN  NaN            NaN
# ..                                ...  ...     ...  ...            ...
# 612                               NaN  ...     NaN  NaN            NaN
# 613                               NaN  ...     NaN  NaN            NaN
# 614                               NaN  ...     NaN  NaN            NaN
# 615                               NaN  ...     NaN  NaN            NaN
# 616                               NaN  ...     NaN  NaN            NaN
#
#     Zona Infantil Piscina comunitaria Serv. portería Internet  \
# 0             NaN                 NaN            NaN      NaN
# 1             NaN                 NaN            NaN      NaN
# 2             NaN                 NaN            NaN      NaN
# 3             NaN                 NaN            NaN      NaN
# 4             NaN                 NaN            NaN      NaN
# ..            ...                 ...            ...      ...
# 612           NaN                 NaN            NaN      NaN
# 613           NaN                 NaN            NaN      NaN
# 614           NaN                 NaN            NaN      NaN
# 615           NaN                 NaN            NaN      NaN
# 616           NaN                 NaN            NaN      NaN
#
#     Suite - con baño Patio Domótica
# 0                NaN   NaN      NaN
# 1                NaN   NaN      NaN
# 2                NaN   NaN      NaN
# 3                NaN   NaN      NaN
# 4                NaN   NaN      NaN
# ..               ...   ...      ...
# 612              NaN   NaN      NaN
# 613              NaN   NaN      NaN
# 614              NaN   NaN      NaN
# 615              NaN   NaN      NaN
# 616              NaN   NaN      NaN
#
# [617 rows x 54 columns]

# %% [markdown]
# ## EJERCICIO 13

# %% [markdown]
# Renombra a continuación la columna Tipo de inmueble de fotocasa1_df por Tipo. Asigna el resultado a la variable fotocasa2_df:

# %%
fotocasa2_df = fotocasa1_df.rename(columns={'Tipo de inmueble': 'Tipo'})
fotocasa2_df.iloc[1]
# Out:
# Precio                                                        500 € /mes
# Título                                 Apartamento de alquiler en Centro
# Descripción            Maravilloso apartamento para entrar a vivir en...
# Fotos                                                           21 Fotos
# Dirección                                                         Centro
# Inmobiliaria                                                        True
# Anunciante                                                BREXTOM MURCIA
# Habitaciones                            <span><span>1</span> hab.</span>
# Baños                                   <span><span>1</span> baño</span>
# Superficie                               <span><span>46</span> m²</span>
# Tipo                                                         Apartamento
# Ascensor                                                              Sí
# Amueblado                                                            NaN
# Depósito                                                             NaN
# Gastos de comunidad                                                  NaN
# Consumo energía                                     G\n999 kW h m² / año
# Emisiones                                  En trámite\n- kg CO₂ m² / año
# Aire acondicionado                                                  True
# Armarios                                                            True
# Electrodomésticos                                                   True
# Horno                                                                NaN
# Lavadora                                                             NaN
# Microondas                                                           NaN
# Nevera                                                               NaN
# Videoportero                                                         NaN
# Puerta Blindada                                                      NaN
# Lavadero                                                             NaN
# Cocina Equipada                                                     True
# Enlace                 https://www.fotocasa.es/es/alquiler/vivienda/m...
# Planta                                                         2ª planta
# Antigüedad                                                  30 a 50 años
# Calefacción                                                         True
# Terraza                                                              NaN
# Balcón                                                               NaN
# Orientación                                                          NaN
# Estado                                                               NaN
# Parking                                                              NaN
# Gres Cerámica                                                        NaN
# Cocina Office                                                        NaN
# Trastero                                                             NaN
# Agua caliente                                                        NaN
# Jardín Privado                                                       NaN
# Parquet                                                              NaN
# Z. Comunitaria                                                       NaN
# Piscina                                                              NaN
# TV                                                                   NaN
# Zona Deportiva                                                       NaN
# Zona Infantil                                                        NaN
# Piscina comunitaria                                                  NaN
# Serv. portería                                                       NaN
# Internet                                                             NaN
# Suite - con baño                                                     NaN
# Patio                                                                NaN
# Domótica                                                             NaN
# Name: 1, dtype: object

# %% [markdown]
# ## EJERCICIO 14

# %% [markdown]
# Elimina del DataFrame aquellos pisos que no tienen Precio o que su Precio sea "A consultar". Asigna el resultado a la variable fotocasa4_df:
#
# PISTA: para seleccionar los alquileres sin precio utiliza el método isnull(). Utiliza notnull() para seleccionar los alquileres con precio..

# %%
fotocasa4_df = fotocasa3_df[~(fotocasa3_df['Precio'].isnull() | (fotocasa3_df['Precio'] == "A consultar"))]
# Alternativa
# fotocasa4_df = fotocasa3_df[fotocasa3_df['Precio'].notnull() & (fotocasa3_df['Precio'] != "A consultar")]
fotocasa4_df.head(3)
# Out:
#        Precio                                     Título  \
# 1  500 € /mes          Apartamento de alquiler en Centro
# 2  900 € /mes  Piso de alquiler en Doctor Marañón Centro
# 3  750 € /mes                 Piso de alquiler en Centro
#
#                                          Descripción     Fotos  \
# 1  Maravilloso apartamento para entrar a vivir en...  21 Fotos
# 2  Se alquila estupenda vivienda recién reformada...  18 Fotos
# 3  Te presentamos este fabuloso apartamento situa...  30 Fotos
#
#                Dirección  Inmobiliaria                    Anunciante  \
# 1                 Centro          True                BREXTOM MURCIA
# 2  Doctor Marañón Centro          True  ABAD SERVICIOS INMOBILIARIOS
# 3                 Centro          True  ABAD SERVICIOS INMOBILIARIOS
#
#                         Habitaciones                              Baños  \
# 1   <span><span>1</span> hab.</span>   <span><span>1</span> baño</span>
# 2  <span><span>4</span> habs.</span>  <span><span>2</span> baños</span>
# 3  <span><span>2</span> habs.</span>   <span><span>1</span> baño</span>
#
#                          Superficie  ... Piscina   TV Zona Deportiva  \
# 1   <span><span>46</span> m²</span>  ...     NaN  NaN            NaN
# 2  <span><span>169</span> m²</span>  ...     NaN  NaN            NaN
# 3   <span><span>77</span> m²</span>  ...     NaN  NaN            NaN
#
#   Zona Infantil Piscina comunitaria Serv. portería Internet Suite - con baño  \
# 1           NaN                 NaN            NaN      NaN              NaN
# 2           NaN                 NaN            NaN      NaN              NaN
# 3           NaN                 NaN            NaN      NaN              NaN
#
#   Patio Domótica
# 1   NaN      NaN
# 2   NaN      NaN
# 3   NaN      NaN
#
# [3 rows x 54 columns]

# %% [markdown]
# ## EJERCICIO 15

# %% [markdown]
# Utiliza la función astype para convertir las columnas Tipo, Orientación, Estado y Parking a tipo categórico. Asigna los resultados a la variable fotocasa5_df y comprueba mediante el parámetro dtype que el tipo asignado sea correcto:

# %%
fotocasa5_df = fotocasa4_df.copy()
fotocasa5_df['Tipo'] = fotocasa5_df['Tipo'].astype("category")
fotocasa5_df['Orientación'] = fotocasa5_df['Orientación'].astype("category")
fotocasa5_df['Estado'] = fotocasa5_df['Estado'].astype("category")
fotocasa5_df['Parking'] = fotocasa5_df['Parking'].astype("category")
for column in ['Tipo', 'Orientación', 'Estado', 'Parking']:
  print(f"Tipo de columna '{column}': {fotocasa5_df[column].dtype}")
fotocasa5_df.head(3)
# Out:
# Tipo de columna 'Tipo': category
# Tipo de columna 'Orientación': category
# Tipo de columna 'Estado': category
# Tipo de columna 'Parking': category
#        Precio                                     Título  \
# 1  500 € /mes          Apartamento de alquiler en Centro
# 2  900 € /mes  Piso de alquiler en Doctor Marañón Centro
# 3  750 € /mes                 Piso de alquiler en Centro
#
#                                          Descripción     Fotos  \
# 1  Maravilloso apartamento para entrar a vivir en...  21 Fotos
# 2  Se alquila estupenda vivienda recién reformada...  18 Fotos
# 3  Te presentamos este fabuloso apartamento situa...  30 Fotos
#
#                Dirección  Inmobiliaria                    Anunciante  \
# 1                 Centro          True                BREXTOM MURCIA
# 2  Doctor Marañón Centro          True  ABAD SERVICIOS INMOBILIARIOS
# 3                 Centro          True  ABAD SERVICIOS INMOBILIARIOS
#
#                         Habitaciones                              Baños  \
# 1   <span><span>1</span> hab.</span>   <span><span>1</span> baño</span>
# 2  <span><span>4</span> habs.</span>  <span><span>2</span> baños</span>
# 3  <span><span>2</span> habs.</span>   <span><span>1</span> baño</span>
#
#                          Superficie  ... Piscina   TV Zona Deportiva  \
# 1   <span><span>46</span> m²</span>  ...     NaN  NaN            NaN
# 2  <span><span>169</span> m²</span>  ...     NaN  NaN            NaN
# 3   <span><span>77</span> m²</span>  ...     NaN  NaN            NaN
#
#   Zona Infantil Piscina comunitaria Serv. portería Internet Suite - con baño  \
# 1           NaN                 NaN            NaN      NaN              NaN
# 2           NaN                 NaN            NaN      NaN              NaN
# 3           NaN                 NaN            NaN      NaN              NaN
#
#   Patio Domótica
# 1   NaN      NaN
# 2   NaN      NaN
# 3   NaN      NaN
#
# [3 rows x 54 columns]

# %% [markdown]
# ## EJERCICIO 16

# %% [markdown]
# Cargar el fichero situado en https://raw.githubusercontent.com/ainaramu-icjardin/big_data/main/ciudades_ejemplo.csv
# como un dataframe Pandas, y guardarlo a continuación en formato excel.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ainaramu-icjardin/big_data/main/ciudades_ejemplo.csv", header = 0, sep=",")
df
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.read_csv("https://raw.githubusercontent.com/ainaramu-icjardin/big_data/main/ciudades_ejemplo.csv", header = 0, sep=",")
#       2 df
#
# File c:\Users\icjardin\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\icjardin\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\icjardin\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\icjardin\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File c:\Users\icjardin\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\icjardin\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File c:\Users\icjardin\anaconda3\Lib\site-packages\pandas\io\common.py:713, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     710     codecs.lookup_error(errors)
#     712 # open URLs
# --> 713 ioargs = _get_filepath_or_buffer(
#     714     path_or_buf,
#     715     encoding=encoding,
#     716     compression=compression,
#     717     mode=mode,
#     718     storage_options=storage_options,
#     719 )
#     721 handle = ioargs.filepath_or_buffer
#     722 handles: list[BaseBuffer]
#
# File c:\Users\icjardin\anaconda3\Lib\site-packages\pandas\io\common.py:363, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     361 # assuming storage_options is to be interpreted as headers
#     362 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 363 with urlopen(req_info) as req:
#     364     content_encoding = req.headers.get("Content-Encoding", None)
#     365     if content_encoding == "gzip":
#     366         # Override compression based on Content-Encoding header
#
# File c:\Users\icjardin\anaconda3\Lib\site-packages\pandas\io\common.py:265, in urlopen(*args, **kwargs)
#     259 """
#     260 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     261 the stdlib.
#     262 """
#     263 import urllib.request
# --> 265 return urllib.request.urlopen(*args, **kwargs)
#
# File c:\Users\icjardin\anaconda3\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File c:\Users\icjardin\anaconda3\Lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File c:\Users\icjardin\anaconda3\Lib\urllib\request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File c:\Users\icjardin\anaconda3\Lib\urllib\request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File c:\Users\icjardin\anaconda3\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\Users\icjardin\anaconda3\Lib\urllib\request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found

# %%
df.to_excel("Datos/ciudades_ejemplo.xlsx")

# %% [markdown]
# ## EJERCICIO 17

# %% [markdown]
# Cargar el fichero "https://raw.githubusercontent.com/ainaramu-icjardin/big_data/main/parocomunidades.csv" que está con codificación (encoding) "latin1" y dejarlo en un dataframe df_paro.
#
# Mostrar solo las filas de `df_paro` que corresponden al Periodo 2019.
#
# Mostrar solo las filas de df_paro que corresponden a un total mayor de 15.
#
# Mostrar solo las filas que corresponden al Periodo 2019 y tienen Total mayor de 15.

# %%
url = "https://raw.githubusercontent.com/ainaramu-icjardin/big_data/main/parocomunidades.csv"
df_paro = pd.read_csv(url, header = 0, sep=",", encoding="latin1")
df_paro
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 url = "https://raw.githubusercontent.com/ainaramu-icjardin/big_data/main/parocomunidades.csv"
# ----> 2 df_paro = pd.read_csv(url, header = 0, sep=",", encoding="latin1")
#       3 df_paro
#
# File c:\Users\icjardin\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\icjardin\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\icjardin\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\icjardin\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File c:\Users\icjardin\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\icjardin\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File c:\Users\icjardin\anaconda3\Lib\site-packages\pandas\io\common.py:713, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     710     codecs.lookup_error(errors)
#     712 # open URLs
# --> 713 ioargs = _get_filepath_or_buffer(
#     714     path_or_buf,
#     715     encoding=encoding,
#     716     compression=compression,
#     717     mode=mode,
#     718     storage_options=storage_options,
#     719 )
#     721 handle = ioargs.filepath_or_buffer
#     722 handles: list[BaseBuffer]
#
# File c:\Users\icjardin\anaconda3\Lib\site-packages\pandas\io\common.py:363, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     361 # assuming storage_options is to be interpreted as headers
#     362 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 363 with urlopen(req_info) as req:
#     364     content_encoding = req.headers.get("Content-Encoding", None)
#     365     if content_encoding == "gzip":
#     366         # Override compression based on Content-Encoding header
#
# File c:\Users\icjardin\anaconda3\Lib\site-packages\pandas\io\common.py:265, in urlopen(*args, **kwargs)
#     259 """
#     260 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     261 the stdlib.
#     262 """
#     263 import urllib.request
# --> 265 return urllib.request.urlopen(*args, **kwargs)
#
# File c:\Users\icjardin\anaconda3\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File c:\Users\icjardin\anaconda3\Lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File c:\Users\icjardin\anaconda3\Lib\urllib\request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File c:\Users\icjardin\anaconda3\Lib\urllib\request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File c:\Users\icjardin\anaconda3\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\Users\icjardin\anaconda3\Lib\urllib\request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found

# %%
filtro = df_paro["Periodo"]==2019
df_paro[filtro]
# Out:
#                 Comunidad  Periodo  Total
# 0               Andalucía     2019  20.80
# 18                 Aragón     2019   9.93
# 36               Asturias     2019  13.14
# 54         Balears. Illes     2019   9.91
# 72               Canarias     2019  18.78
# 90              Cantabria     2019  11.18
# 108       Castilla y León     2019  11.20
# 126  Castilla - La Mancha     2019  16.56
# 144              Cataluña     2019  10.45
# 162  Comunitat Valenciana     2019  14.13
# 180           Extremadura     2019  23.48
# 198               Galicia     2019  11.74
# 216                Madrid     2019   9.99
# 234                Murcia     2019  16.08
# 252               Navarra     2019   9.01
# 270            País Vasco     2019   9.09
# 288              La Rioja     2019   9.89
# 306                 Ceuta     2019  27.58
# 324               Melilla     2019  26.81

# %%
filtro = df_paro["Total"]>=15 
df_paro[filtro]
# Out:
#      Comunidad  Periodo  Total
# 0    Andalucía     2019  20.80
# 1    Andalucía     2018  21.26
# 2    Andalucía     2017  24.43
# 3    Andalucía     2016  28.25
# 4    Andalucía     2015  29.83
# ..         ...      ...    ...
# 333    Melilla     2010  24.46
# 334    Melilla     2009  19.87
# 335    Melilla     2008  16.17
# 336    Melilla     2007  17.43
# 340    Melilla     2003  19.88
#
# [163 rows x 3 columns]

# %%
filtro = (df_paro["Total"]>=15) & (df_paro["Periodo"]==2019)
df_paro[filtro]
# Out:
#                 Comunidad  Periodo  Total
# 0               Andalucía     2019  20.80
# 72               Canarias     2019  18.78
# 126  Castilla - La Mancha     2019  16.56
# 180           Extremadura     2019  23.48
# 234                Murcia     2019  16.08
# 306                 Ceuta     2019  27.58
# 324               Melilla     2019  26.81

# %% [markdown]
# ## <ins>Ejercicios Opcionales </ins>

# %% [markdown]
# ## EJERCICIO 18

# %% [markdown]
# Investiga el método .sort_values() para ordenar las observaciones según la longitud de las palabras en orden descendente.

# %%
print(words.sort_values('length',ascending=False))
# Out:
#       words  length  vocals  consonants
# 9  boutique       8       5           3
# 8   hazañas       7       3           4
# 4    cicuta       6       3           3
# 5    fatiga       6       3           3
# 6    nachos       6       2           4
# 7    jadeos       6       3           3
# 2     algas       5       2           3
# 3     broma       5       2           3
# 0      euro       4       3           1
# 1      diez       4       2           2

# %% [markdown]
# ## EJERCICIO 19

# %% [markdown]
# Convierte la columna vowels a lista y, con sorted() ordénala de mayor a menor. Investiga para ello el método .tolist().

# %%
numVocales=sorted(words['vocals'].tolist(),reverse=True)
print(numVocales)
# Out:
# [5, 3, 3, 3, 3, 3, 2, 2, 2, 2]

# %% [markdown]
# ## EJERCICIO 20

# %% [markdown]
# Recupera aquellos pisos que ocupan una posición múltiplo de 100:

# %%
fotocasa_df[::100]
# Out:
#           Precio                                             Título  \
# 0    A consultar                         Piso de alquiler en Centro
# 100   540 € /mes  Piso de alquiler en C/ José Hernández - Ed Alc...
# 200   700 € /mes                  Apartamento de alquiler en Centro
# 300   850 € /mes      Piso de alquiler en Juan de Borbón - La Flota
# 400   700 € /mes                         Piso de alquiler en Centro
# 500   550 € /mes  Piso de alquiler en Calle del Platanito Vistab...
# 600          NaN  Alquiler piso exclusiva vivienda en el Centro ...
#
#                                            Descripción     Fotos  \
# 0    TRABAJADORES Y ESTUDIANTES ATENCION!!!! VIVIEN...  18 Fotos
# 100  PROMOCIÓN: 1 MES DE ALQUILER GRATIS si reserva...  27 Fotos
# 200  Alquiler de apartamento en el centro, junto a ...  19 Fotos
# 300  Piso completamente amueblado y cocina equipada...  13 Fotos
# 400  Piso completamente amueblado y cocina equipada...  10 Fotos
# 500  Vivienda 4 dormitorios en Avenida de la Fama! ...   9 Fotos
# 600                                                NaN       NaN
#
#                                            Dirección  Inmobiliaria  \
# 0                                             Centro          True
# 100  C/ José Hernández - Ed Alcántara II - Espinardo          True
# 200                                           Centro          True
# 300                        Juan de Borbón - La Flota          True
# 400                                           Centro          True
# 500                   Calle del Platanito Vistabella          True
# 600                                              NaN          True
#
#                              Anunciante                       Habitaciones  \
# 0              DPTO. COMERCIAL PISOSMUR  <span><span>4</span> habs.</span>
# 100  SOLVIA SERVICIOS INMOBILIARIOS S.L  <span><span>2</span> habs.</span>
# 200              BASCUÑANA INMOBILIARIA  <span><span>2</span> habs.</span>
# 300   THE SIMPLE RENT LUXURY PROPERTIES  <span><span>3</span> habs.</span>
# 400                         OPAU MURCIA  <span><span>2</span> habs.</span>
# 500                            LOGAR 21  <span><span>4</span> habs.</span>
# 600                                 NaN                                NaN
#
#                                  Baños                        Superficie  ...  \
# 0    <span><span>2</span> baños</span>  <span><span>110</span> m²</span>  ...
# 100   <span><span>1</span> baño</span>   <span><span>82</span> m²</span>  ...
# 200  <span><span>2</span> baños</span>   <span><span>70</span> m²</span>  ...
# 300  <span><span>2</span> baños</span>   <span><span>90</span> m²</span>  ...
# 400  <span><span>2</span> baños</span>   <span><span>45</span> m²</span>  ...
# 500   <span><span>1</span> baño</span>   <span><span>95</span> m²</span>  ...
# 600                                NaN                               NaN  ...
#
#     Serv. portería Internet Suite - con baño Patio Domótica Pista de Tenis  \
# 0              NaN      NaN              NaN   NaN      NaN            NaN
# 100            NaN      NaN              NaN   NaN      NaN            NaN
# 200            NaN      NaN              NaN   NaN      NaN            NaN
# 300            NaN      NaN             True   NaN      NaN            NaN
# 400            NaN      NaN              NaN   NaN      NaN            NaN
# 500            NaN      NaN              NaN   NaN      NaN            NaN
# 600            NaN      NaN              NaN   NaN      NaN            NaN
#
#     Alarma Mascotas Energía Solar Gimnasio
# 0      NaN      NaN           NaN      NaN
# 100    NaN      NaN           NaN      NaN
# 200    NaN      NaN           NaN      NaN
# 300    NaN      NaN           NaN      NaN
# 400    NaN      NaN           NaN      NaN
# 500    NaN      NaN           NaN      NaN
# 600    NaN      NaN           NaN      NaN
#
# [7 rows x 59 columns]

# %% [markdown]
# ## EJERCICIO 21

# %% [markdown]
# Muestra el piso que se encuentra en la posición 7:

# %%
fotocasa_df.iloc[7]
# Out:
# Precio                                                        300 € /mes
# Título                                  Estudio de alquiler en Barriomar
# Descripción            Estudio equipado completo. Cocina con electrod...
# Fotos                                                            5 Fotos
# Dirección                                                      Barriomar
# Inmobiliaria                                                        True
# Anunciante                                                   OPAU MURCIA
# Habitaciones                                                         NaN
# Baños                                   <span><span>1</span> baño</span>
# Superficie                               <span><span>35</span> m²</span>
# Tipo de inmueble                                                 Estudio
# Ascensor                                                              Sí
# Amueblado                                                             Sí
# Depósito                                                             NaN
# Gastos de comunidad                                                  NaN
# Consumo energía                                     G\n999 kW h m² / año
# Emisiones                                  En trámite\n- kg CO₂ m² / año
# Aire acondicionado                                                  True
# Armarios                                                             NaN
# Electrodomésticos                                                    NaN
# Horno                                                                NaN
# Lavadora                                                             NaN
# Microondas                                                           NaN
# Nevera                                                               NaN
# Videoportero                                                         NaN
# Puerta Blindada                                                      NaN
# Lavadero                                                             NaN
# Cocina Equipada                                                     True
# Enlace                 https://www.fotocasa.es/es/alquiler/vivienda/m...
# Planta                                                         1ª planta
# Antigüedad                                                           NaN
# Calefacción                                                          NaN
# Terraza                                                              NaN
# Balcón                                                              True
# Orientación                                                          NaN
# Estado                                                              Bien
# Parking                                                              NaN
# Gres Cerámica                                                        NaN
# Cocina Office                                                        NaN
# Trastero                                                             NaN
# Agua caliente                                                        NaN
# Jardín Privado                                                       NaN
# Parquet                                                              NaN
# Z. Comunitaria                                                       NaN
# Piscina                                                              NaN
# TV                                                                   NaN
# Zona Deportiva                                                       NaN
# Zona Infantil                                                        NaN
# Piscina comunitaria                                                  NaN
# Serv. portería                                                       NaN
# Internet                                                             NaN
# Suite - con baño                                                     NaN
# Patio                                                                NaN
# Domótica                                                             NaN
# Pista de Tenis                                                       NaN
# Alarma                                                               NaN
# Mascotas                                                             NaN
# Energía Solar                                                        NaN
# Gimnasio                                                             NaN
# Name: 7, dtype: object

# %% [markdown]
# ## EJERCICIO 22

# %% [markdown]
# Muestra el piso cuyo índice vale 9:

# %%
fotocasa_df.loc[9]
# Out:
# Precio                                                      1.400 € /mes
# Título                                        Piso de alquiler en Centro
# Descripción            Piso de 3 dormitorios, equipados completos, la...
# Fotos                                                           16 Fotos
# Dirección                                                         Centro
# Inmobiliaria                                                        True
# Anunciante                             THE SIMPLE RENT LUXURY PROPERTIES
# Habitaciones                           <span><span>3</span> habs.</span>
# Baños                                  <span><span>2</span> baños</span>
# Superficie                              <span><span>150</span> m²</span>
# Tipo de inmueble                                                    Piso
# Ascensor                                                              Sí
# Amueblado                                                             Sí
# Depósito                                                             NaN
# Gastos de comunidad                                                   Sí
# Consumo energía                                     G\n999 kW h m² / año
# Emisiones                                  En trámite\n- kg CO₂ m² / año
# Aire acondicionado                                                  True
# Armarios                                                             NaN
# Electrodomésticos                                                   True
# Horno                                                                NaN
# Lavadora                                                            True
# Microondas                                                           NaN
# Nevera                                                              True
# Videoportero                                                         NaN
# Puerta Blindada                                                      NaN
# Lavadero                                                             NaN
# Cocina Equipada                                                     True
# Enlace                 https://www.fotocasa.es/es/alquiler/vivienda/m...
# Planta                                                         3ª planta
# Antigüedad                                                           NaN
# Calefacción                                                          NaN
# Terraza                                                              NaN
# Balcón                                                               NaN
# Orientación                                                          NaN
# Estado                                                               NaN
# Parking                                                      Comunitario
# Gres Cerámica                                                        NaN
# Cocina Office                                                        NaN
# Trastero                                                             NaN
# Agua caliente                                                        NaN
# Jardín Privado                                                       NaN
# Parquet                                                              NaN
# Z. Comunitaria                                                       NaN
# Piscina                                                              NaN
# TV                                                                   NaN
# Zona Deportiva                                                       NaN
# Zona Infantil                                                        NaN
# Piscina comunitaria                                                  NaN
# Serv. portería                                                       NaN
# Internet                                                             NaN
# Suite - con baño                                                     NaN
# Patio                                                                NaN
# Domótica                                                             NaN
# Pista de Tenis                                                       NaN
# Alarma                                                               NaN
# Mascotas                                                             NaN
# Energía Solar                                                        NaN
# Gimnasio                                                             NaN
# Name: 9, dtype: object

# %% [markdown]
# ## EJERCICIO 23

# %% [markdown]
# Muestra el campo Dirección de los tres primeros pisos. Utiliza para ello tanto el operador ```[]``` como ```[[]]```. ¿Qué diferencia encuentras?

# %%
fotocasa_df.head(3)['Dirección']
# Out:
# 0                   Centro
# 1                   Centro
# 2    Doctor Marañón Centro
# Name: Dirección, dtype: object

# %%
fotocasa_df.head(3)[['Dirección']]
# Out:
#                Dirección
# 0                 Centro
# 1                 Centro
# 2  Doctor Marañón Centro

# %% [markdown]
# ## EJERCICIO 24

# %% [markdown]
# Muestra los campos Inmobiliaria y Tipo de inmueble de los tres últimos pisos:

# %%
fotocasa_df.tail(3)[["Inmobiliaria", "Tipo de inmueble"]]
# Out:
#      Inmobiliaria Tipo de inmueble
# 614          True              NaN
# 615          True              NaN
# 616          True              NaN

# %% [markdown]
# ## EJERCICIO 25

# %% [markdown]
# Muestra el valor del DataFrame contenido en la posición (2,2):

# %%
fotocasa_df.iat[2,2]
# Out:
# 'Se alquila estupenda vivienda recién reformada en pleno centro de Murcia junto a la Avenida Constitución . Cuenta con 4 dormitorios muy amplios, dos baños, cocina independiente amueblada con electrodomésticos y terraza acristalada. La vivienda se alquila sin muebles, .con los gastos de la comunidad incluidos en el precio, que incluye también el coste de la calefacción. El edificio cuenta con portero físico y está en zona inmejorable con todo tipo de servicios alrededor. Por expreso deseo del propietario, este inmueble lo comercializamos en exclusiva. Nuestros asesores le facilitarán toda la información que precise, por lo que le rogamos no moleste al propietario o a los vecinos. Y si usted es una agencia inmobiliaria y tiene un cliente interesado, póngase en contacto con nosotros y estaremos encantados de colaborar.'

# %%
fotocasa_df.iloc[2,2]
# Out:
# 'Se alquila estupenda vivienda recién reformada en pleno centro de Murcia junto a la Avenida Constitución . Cuenta con 4 dormitorios muy amplios, dos baños, cocina independiente amueblada con electrodomésticos y terraza acristalada. La vivienda se alquila sin muebles, .con los gastos de la comunidad incluidos en el precio, que incluye también el coste de la calefacción. El edificio cuenta con portero físico y está en zona inmejorable con todo tipo de servicios alrededor. Por expreso deseo del propietario, este inmueble lo comercializamos en exclusiva. Nuestros asesores le facilitarán toda la información que precise, por lo que le rogamos no moleste al propietario o a los vecinos. Y si usted es una agencia inmobiliaria y tiene un cliente interesado, póngase en contacto con nosotros y estaremos encantados de colaborar.'

# %% [markdown]
# ## EJERCICIO 26

# %% [markdown]
# Muestra el valor del DataFrame cuyo índice es 2 y cuya columna es Título:

# %%
fotocasa_df.at[2, "Título"]
# Out:
# 'Piso de alquiler en Doctor Marañón Centro'

# %%
fotocasa_df.loc[2,"Título"]
# Out:
# 'Piso de alquiler en Doctor Marañón Centro'

# %% [markdown]
# ## EJERCICIO 27

# %% [markdown]
# Muestra los tres primeros inmuebles de Tipo de inmueble = Apartamento:

# %%
fotocasa_df[fotocasa_df["Tipo de inmueble"] == "Apartamento"].head(3)
# Out:
#         Precio                                Título  \
# 1   500 € /mes     Apartamento de alquiler en Centro
# 12  500 € /mes  Apartamento de alquiler en Espinardo
# 15  400 € /mes  Apartamento de alquiler en El Carmen
#
#                                           Descripción     Fotos  Dirección  \
# 1   Maravilloso apartamento para entrar a vivir en...  21 Fotos     Centro
# 12  Apartamento de 1 dormitorio,totalmente amuebla...   8 Fotos  Espinardo
# 15  Apartamento con 1 dormitorio independiente, eq...   5 Fotos  El Carmen
#
#     Inmobiliaria      Anunciante                      Habitaciones  \
# 1           True  BREXTOM MURCIA  <span><span>1</span> hab.</span>
# 12          True     OPAU MURCIA  <span><span>1</span> hab.</span>
# 15          True     OPAU MURCIA  <span><span>1</span> hab.</span>
#
#                                Baños                       Superficie  ...  \
# 1   <span><span>1</span> baño</span>  <span><span>46</span> m²</span>  ...
# 12  <span><span>1</span> baño</span>  <span><span>40</span> m²</span>  ...
# 15  <span><span>1</span> baño</span>  <span><span>33</span> m²</span>  ...
#
#    Serv. portería Internet Suite - con baño Patio Domótica Pista de Tenis  \
# 1             NaN      NaN              NaN   NaN      NaN            NaN
# 12            NaN      NaN              NaN   NaN      NaN            NaN
# 15            NaN      NaN              NaN   NaN      NaN            NaN
#
#    Alarma Mascotas Energía Solar Gimnasio
# 1     NaN      NaN           NaN      NaN
# 12    NaN      NaN           NaN      NaN
# 15    NaN      NaN           NaN      NaN
#
# [3 rows x 59 columns]

# %% [markdown]
# ## EJERCICIO 28

# %% [markdown]
# Muestra los dos primeros inmuebles de Tipo de inmueble = Piso y que no se alquilen por inmobiliaria (Inmobiliaria = False):

# %%
fotocasa_df[(fotocasa_df["Tipo de inmueble"] == "Piso") & (fotocasa_df["Inmobiliaria"] == False)].head(2)
# Out:
#         Precio                                             Título  \
# 36  550 € /mes  Piso de alquiler en Calle Joaquín Báguena, 10 ...
# 38  560 € /mes  Piso de alquiler en Avenida del Palmar, 44 Ron...
#
#                                           Descripción     Fotos  \
# 36  Alquilo piso centrico y muy cuidado, con parqu...  15 Fotos
# 38  RONDA SUR (Zona innovadora)\nParticular (Sin c...  20 Fotos
#
#                            Dirección  Inmobiliaria  \
# 36  Calle Joaquín Báguena, 10 Centro         False
# 38  Avenida del Palmar, 44 Ronda Sur         False
#
#                                            Anunciante  \
# 36  <span class="re-ContactDetail-particularLabel"...
# 38  <span class="re-ContactDetail-particularLabel"...
#
#                          Habitaciones                             Baños  \
# 36  <span><span>2</span> habs.</span>  <span><span>1</span> baño</span>
# 38  <span><span>2</span> habs.</span>  <span><span>1</span> baño</span>
#
#                          Superficie  ... Serv. portería Internet  \
# 36  <span><span>53</span> m²</span>  ...            NaN      NaN
# 38  <span><span>78</span> m²</span>  ...            NaN      NaN
#
#    Suite - con baño Patio Domótica Pista de Tenis Alarma Mascotas  \
# 36              NaN   NaN      NaN            NaN    NaN      NaN
# 38              NaN   NaN      NaN            NaN    NaN      NaN
#
#    Energía Solar Gimnasio
# 36           NaN      NaN
# 38           NaN      NaN
#
# [2 rows x 59 columns]

# %% [markdown]
# ## EJERCICIO 29

# %% [markdown]
# Elimina del DataFrame contenido en fotocasa2_df los alquileres de la posición 597 y 598. Asigna el resultado a fotocasa3_df:

# %%
fotocasa3_df = fotocasa2_df.drop([597,598])
fotocasa3_df.tail(30)
# Out:
#           Precio                                             Título  \
# 585  A consultar                         Piso de alquiler en Centro
# 586   750 € /mes           Apartamento de alquiler en Juan Carlos I
# 587   900 € /mes    Piso de alquiler en Plaza Plaza Preciosa Centro
# 588   660 € /mes                  Piso de alquiler en Juan Carlos I
# 589   600 € /mes  Piso de alquiler en Calle Jorge Guillén Juan C...
# 590   800 € /mes          Piso de alquiler en Santa María de Gracia
# 591   800 € /mes          Piso de alquiler en Santa María de Gracia
# 592  A consultar                         Piso de alquiler en Centro
# 593   800 € /mes          Piso de alquiler en Calle Joselito Centro
# 594  A consultar                         Piso de alquiler en Centro
# 595  A consultar                         Piso de alquiler en Centro
# 596   850 € /mes                         Piso de alquiler en Centro
# 599          NaN  Alquiler piso alquiler piso zona belen en Vist...
# 600          NaN  Alquiler piso exclusiva vivienda en el Centro ...
# 601          NaN  Alquiler dúplex estupendo triplex en alquiler ...
# 602          NaN  Alquiler piso alquiler en juan carlos i en Vis...
# 603          NaN  Alquiler piso de 4 habitaciones con plaza de g...
# 604          NaN  Alquiler apartamento céntrico en El Carmen Murcia
# 605          NaN  Alquiler piso estudiantes, alquiler en Vistale...
# 606          NaN  Alquiler piso (zona juan de borbon) en Vistale...
# 607          NaN  Alquiler piso estudiantes alquiler plaza juan ...
# 608          NaN  Alquiler piso alquiler de piso en Espinardo-ju...
# 609          NaN  Alquiler piso en calle andres sobejano se vend...
# 610          NaN       Alquiler apartamento juan carlos i en Murcia
# 611          NaN  Alquiler apartamento vivienda junto cuartel de...
# 612          NaN  Alquiler piso en barrio dEl Carmen en El Carme...
# 613          NaN  Alquiler apartamento en plaza san nicolas en M...
# 614          NaN  Alquiler apartamento exclusivo apto plaza flor...
# 615          NaN  Alquiler piso alquiler de local entresuelo en ...
# 616          NaN  Alquiler piso en alquiler en edificio alba, sa...
#
#                                            Descripción     Fotos  \
# 585  ATENCION ESTUDIANTE PISO CERCANO A LA MERCED, ...   9 Fotos
# 586  MAGNIFICO APARTAMENTO EN AVENIDA DE EUROPA, DO...  14 Fotos
# 587  ATENCIÓN ESTUDIANTES!!!! SE ALQUILA MAGNIFICA ...  16 Fotos
# 588  ATENCIÓN ESTUDIANTES VIVIENDA REFORMADA EN VIS...   9 Fotos
# 589  ATENCION ESTUDIANTES!!!! BARRIO DE VISTA ALEGR...  10 Fotos
# 590  ATENCIÓN ESTUDIANTES VIVIENDA JUNTO A LA PLAZA...   9 Fotos
# 591  ATENCIÓN ESTUDIANTES MAGNIFICO PISOS EN SANTA ...  11 Fotos
# 592  FANTASTICO PISO EN AVENIDA GENERAL PRIMO DE RI...   9 Fotos
# 593  ATENCIÓN ESTUDIANTES!!!!MAGNIFICA VIVIENDA JUN...  10 Fotos
# 594  ESTUDIATES JUNTO A LA MERCED 4 DORMITORIOS, FA...  15 Fotos
# 595  ATENCION ESTUDIANTES VIVIENDA DE 4 DORMITORIOS...  11 Fotos
# 596  ATENCIÓN ESTUDIANTES, MAGNIFICA VIVIENDA EN CA...  10 Fotos
# 599                                                NaN       NaN
# 600                                                NaN       NaN
# 601                                                NaN       NaN
# 602                                                NaN       NaN
# 603                                                NaN       NaN
# 604                                                NaN       NaN
# 605                                                NaN       NaN
# 606                                                NaN       NaN
# 607                                                NaN       NaN
# 608                                                NaN       NaN
# 609                                                NaN       NaN
# 610                                                NaN       NaN
# 611                                                NaN       NaN
# 612                                                NaN       NaN
# 613                                                NaN       NaN
# 614                                                NaN       NaN
# 615                                                NaN       NaN
# 616                                                NaN       NaN
#
#                              Dirección  Inmobiliaria  \
# 585                             Centro          True
# 586                      Juan Carlos I          True
# 587        Plaza Plaza Preciosa Centro          True
# 588                      Juan Carlos I          True
# 589  Calle Jorge Guillén Juan Carlos I          True
# 590              Santa María de Gracia          True
# 591              Santa María de Gracia          True
# 592                             Centro          True
# 593              Calle Joselito Centro          True
# 594                             Centro          True
# 595                             Centro          True
# 596                             Centro          True
# 599                                NaN          True
# 600                                NaN          True
# 601                                NaN          True
# 602                                NaN          True
# 603                                NaN          True
# 604                                NaN          True
# 605                                NaN          True
# 606                                NaN          True
# 607                                NaN          True
# 608                                NaN          True
# 609                                NaN          True
# 610                                NaN          True
# 611                                NaN          True
# 612                                NaN          True
# 613                                NaN          True
# 614                                NaN          True
# 615                                NaN          True
# 616                                NaN          True
#
#                    Anunciante                       Habitaciones  \
# 585  DPTO. COMERCIAL PISOSMUR  <span><span>3</span> habs.</span>
# 586  DPTO. COMERCIAL PISOSMUR  <span><span>2</span> habs.</span>
# 587  DPTO. COMERCIAL PISOSMUR  <span><span>4</span> habs.</span>
# 588  DPTO. COMERCIAL PISOSMUR  <span><span>3</span> habs.</span>
# 589  DPTO. COMERCIAL PISOSMUR  <span><span>3</span> habs.</span>
# 590  DPTO. COMERCIAL PISOSMUR  <span><span>4</span> habs.</span>
# 591  DPTO. COMERCIAL PISOSMUR  <span><span>4</span> habs.</span>
# 592  DPTO. COMERCIAL PISOSMUR  <span><span>3</span> habs.</span>
# 593  DPTO. COMERCIAL PISOSMUR  <span><span>4</span> habs.</span>
# 594  DPTO. COMERCIAL PISOSMUR  <span><span>4</span> habs.</span>
# 595  DPTO. COMERCIAL PISOSMUR  <span><span>4</span> habs.</span>
# 596  DPTO. COMERCIAL PISOSMUR  <span><span>4</span> habs.</span>
# 599                       NaN                                NaN
# 600                       NaN                                NaN
# 601                       NaN                                NaN
# 602                       NaN                                NaN
# 603                       NaN                                NaN
# 604                       NaN                                NaN
# 605                       NaN                                NaN
# 606                       NaN                                NaN
# 607                       NaN                                NaN
# 608                       NaN                                NaN
# 609                       NaN                                NaN
# 610                       NaN                                NaN
# 611                       NaN                                NaN
# 612                       NaN                                NaN
# 613                       NaN                                NaN
# 614                       NaN                                NaN
# 615                       NaN                                NaN
# 616                       NaN                                NaN
#
#                                  Baños                        Superficie  ...  \
# 585   <span><span>1</span> baño</span>  <span><span>100</span> m²</span>  ...
# 586   <span><span>1</span> baño</span>   <span><span>70</span> m²</span>  ...
# 587  <span><span>2</span> baños</span>  <span><span>120</span> m²</span>  ...
# 588   <span><span>1</span> baño</span>   <span><span>80</span> m²</span>  ...
# 589  <span><span>2</span> baños</span>   <span><span>80</span> m²</span>  ...
# 590  <span><span>2</span> baños</span>  <span><span>115</span> m²</span>  ...
# 591  <span><span>2</span> baños</span>  <span><span>130</span> m²</span>  ...
# 592   <span><span>1</span> baño</span>                               NaN  ...
# 593  <span><span>2</span> baños</span>  <span><span>100</span> m²</span>  ...
# 594  <span><span>2</span> baños</span>  <span><span>130</span> m²</span>  ...
# 595  <span><span>2</span> baños</span>                               NaN  ...
# 596  <span><span>2</span> baños</span>                               NaN  ...
# 599                                NaN                               NaN  ...
# 600                                NaN                               NaN  ...
# 601                                NaN                               NaN  ...
# 602                                NaN                               NaN  ...
# 603                                NaN                               NaN  ...
# 604                                NaN                               NaN  ...
# 605                                NaN                               NaN  ...
# 606                                NaN                               NaN  ...
# 607                                NaN                               NaN  ...
# 608                                NaN                               NaN  ...
# 609                                NaN                               NaN  ...
# 610                                NaN                               NaN  ...
# 611                                NaN                               NaN  ...
# 612                                NaN                               NaN  ...
# 613                                NaN                               NaN  ...
# 614                                NaN                               NaN  ...
# 615                                NaN                               NaN  ...
# 616                                NaN                               NaN  ...
#
#     Piscina    TV Zona Deportiva Zona Infantil Piscina comunitaria  \
# 585     NaN   NaN            NaN           NaN                 NaN
# 586     NaN  True            NaN           NaN                 NaN
# 587     NaN   NaN            NaN           NaN                 NaN
# 588     NaN  True            NaN           NaN                 NaN
# 589     NaN   NaN            NaN           NaN                 NaN
# 590     NaN   NaN            NaN           NaN                 NaN
# 591     NaN   NaN            NaN           NaN                 NaN
# 592     NaN  True            NaN           NaN                 NaN
# 593     NaN   NaN            NaN           NaN                 NaN
# 594     NaN  True            NaN           NaN                 NaN
# 595     NaN   NaN            NaN           NaN                 NaN
# 596     NaN  True            NaN           NaN                 NaN
# 599     NaN   NaN            NaN           NaN                 NaN
# 600     NaN   NaN            NaN           NaN                 NaN
# 601     NaN   NaN            NaN           NaN                 NaN
# 602     NaN   NaN            NaN           NaN                 NaN
# 603     NaN   NaN            NaN           NaN                 NaN
# 604     NaN   NaN            NaN           NaN                 NaN
# 605     NaN   NaN            NaN           NaN                 NaN
# 606     NaN   NaN            NaN           NaN                 NaN
# 607     NaN   NaN            NaN           NaN                 NaN
# 608     NaN   NaN            NaN           NaN                 NaN
# 609     NaN   NaN            NaN           NaN                 NaN
# 610     NaN   NaN            NaN           NaN                 NaN
# 611     NaN   NaN            NaN           NaN                 NaN
# 612     NaN   NaN            NaN           NaN                 NaN
# 613     NaN   NaN            NaN           NaN                 NaN
# 614     NaN   NaN            NaN           NaN                 NaN
# 615     NaN   NaN            NaN           NaN                 NaN
# 616     NaN   NaN            NaN           NaN                 NaN
#
#     Serv. portería Internet Suite - con baño Patio Domótica
# 585            NaN      NaN              NaN   NaN      NaN
# 586            NaN      NaN              NaN   NaN      NaN
# 587            NaN      NaN              NaN   NaN      NaN
# 588            NaN      NaN              NaN   NaN      NaN
# 589            NaN      NaN              NaN  True      NaN
# 590            NaN      NaN              NaN   NaN      NaN
# 591            NaN      NaN              NaN   NaN      NaN
# 592           True      NaN              NaN   NaN      NaN
# 593            NaN      NaN              NaN   NaN      NaN
# 594            NaN      NaN              NaN   NaN      NaN
# 595            NaN      NaN              NaN   NaN      NaN
# 596            NaN      NaN              NaN   NaN      NaN
# 599            NaN      NaN              NaN   NaN      NaN
# 600            NaN      NaN              NaN   NaN      NaN
# 601            NaN      NaN              NaN   NaN      NaN
# 602            NaN      NaN              NaN   NaN      NaN
# 603            NaN      NaN              NaN   NaN      NaN
# 604            NaN      NaN              NaN   NaN      NaN
# 605            NaN      NaN              NaN   NaN      NaN
# 606            NaN      NaN              NaN   NaN      NaN
# 607            NaN      NaN              NaN   NaN      NaN
# 608            NaN      NaN              NaN   NaN      NaN
# 609            NaN      NaN              NaN   NaN      NaN
# 610            NaN      NaN              NaN   NaN      NaN
# 611            NaN      NaN              NaN   NaN      NaN
# 612            NaN      NaN              NaN   NaN      NaN
# 613            NaN      NaN              NaN   NaN      NaN
# 614            NaN      NaN              NaN   NaN      NaN
# 615            NaN      NaN              NaN   NaN      NaN
# 616            NaN      NaN              NaN   NaN      NaN
#
# [30 rows x 54 columns]
